# %%
# Simple Calculator

print("===== SIMPLE CALCULATOR =====")

num1 = float(input("Enter first number: "))
operator = input("Enter operator (+, -, *, /, //, %, **): ")
num2 = float(input("Enter second number: "))

if operator == "+":
    result = num1 + num2

elif operator == "-":
    result = num1 - num2

elif operator == "*":
    result = num1 * num2

elif operator == "/":
    if num2 == 0:
        print("Error: Division by zero is not allowed.")
    else:
        result = num1 / num2
        print(f"\nResult: {num1} / {num2} = {result:.4f}")

        if result > 0:
            print("The result is positive.")
        elif result < 0:
            print("The result is negative.")
        else:
            print("The result is zero.")

elif operator == "//":
    if num2 == 0:
        print("Error: Division by zero is not allowed.")
    else:
        result = num1 // num2

elif operator == "%":
    if num2 == 0:
        print("Error: Division by zero is not allowed.")
    else:
        result = num1 % num2

elif operator == "**":
    result = num1 ** num2

else:
    print("Invalid operator.")

# Display result for all operators except /
if operator in ["+", "-", "*", "//", "%", "**"]:
    print(f"\nResult: {num1} {operator} {num2} = {result}")

    if result > 0:
        print("The result is positive.")
    elif result < 0:
        print("The result is negative.")
    else:
        print("The result is zero.")

print("==============================")
# Out:
# ===== SIMPLE CALCULATOR =====
# Enter first number:  45
# Enter operator (+, -, *, /, //, %, **):  +
# Enter second number:  50
# Result: 45.0 + 50.0 = 95.0
# The result is positive.
# ==============================
